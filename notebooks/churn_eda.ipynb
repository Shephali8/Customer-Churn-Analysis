# %% [markdown]
# # Customer Churn EDA
# This notebook performs exploratory data analysis on the churn dataset.
#
# ### Steps:
# - Load dataset
# - Check missing values
# - Univariate analysis (Age, Gender, Charges)
# - Bivariate analysis (Churn vs Tenure, Churn vs Charges)
# - Correlation heatmap

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/churn_sample.csv')
df.head()
